# %% [markdown]
# Energy consumption across different regions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys
sys.path.append('../code/')

# %%
from common import *

# %%
year = 2014
means = {}
for source in ['Austin','SanDiego','Boulder']:
    source_df, source_dfc, source_tensor, source_static = create_region_df_dfc_static(source, year)
    means[source] = source_df[['aggregate_{}'.format(month) for month in range(1, 13)]].mean()
    means[source].index = range(1, 13)

# %%
pd.DataFrame(means).plot()
plt.xlabel("Month of year")
plt.ylabel("Energy")

# %%
year = 2014
means = {}
for source in ['Austin','SanDiego','Boulder']:
    source_df, source_dfc, source_tensor, source_static = create_region_df_dfc_static(source, year)
    means[source] = {}
    for appliance in APPLIANCES_ORDER:
        means[source][appliance] = source_df[['{}_{}'.format(appliance, month) for month in range(1, 13)]].mean()
        means[source][appliance].index = range(1, 13)

fig, ax  = plt.subplots(ncols=3, figsize=(12, 3))
for col, region in enumerate(['Austin','SanDiego','Boulder']):
    (pd.DataFrame(means[region])[APPLIANCES_ORDER[1:]]).plot(kind='area', stacked=True, ax=ax[col], legend=False)
    pd.DataFrame(means[region])['aggregate'].plot(ax=ax[col], title="{}-{}".format(region, year), legend=False)
ax[0].set_ylim((0, 1500))    
ax[1].set_ylim((0, 700)) 
ax[2].set_ylim((0, 800))    
plt.legend(bbox_to_anchor=(1.1, 1))

# %%
year = 2015
means = {}
for source in ['Austin','SanDiego','Boulder']:
    source_df, source_dfc, source_tensor, source_static = create_region_df_dfc_static(source, year)
    means[source] = {}
    for appliance in APPLIANCES_ORDER:
        means[source][appliance] = source_df[['{}_{}'.format(appliance, month) for month in range(1, 13)]].mean()
        means[source][appliance].index = range(1, 13)

fig, ax  = plt.subplots(ncols=3, figsize=(12, 3))
for col, region in enumerate(['Austin','SanDiego','Boulder']):
    (pd.DataFrame(means[region])[APPLIANCES_ORDER[1:]]).plot(kind='area', stacked=True, ax=ax[col], legend=False)
    pd.DataFrame(means[region])['aggregate'].plot(ax=ax[col], title="{}-{}".format(region, year), legend=False)
ax[0].set_ylim((0, 1500))    
ax[1].set_ylim((0, 700)) 
ax[2].set_ylim((0, 800))    
plt.legend(bbox_to_anchor=(1.1, 1))

# %%
region = 'SanDiego'
(pd.DataFrame(means[region])[APPLIANCES_ORDER[1:]]).plot(kind='area', stacked=True)
pd.DataFrame(means[region])['aggregate'].plot()
plt.ylim((0, 700))
# Out:
# (0, 700)

# %%
region = 'Boulder'
(pd.DataFrame(means[region])[APPLIANCES_ORDER[1:]]).plot(kind='area', stacked=True)
pd.DataFrame(means[region])['aggregate'].plot()
plt.ylim((0, 800))
# Out:
# (0, 800)

# %%
pd.DataFrame(means['Boulder']).plot(kind='area', stacked=False)

# %%
year = 2015
means = {}
for source in ['Austin','SanDiego','Boulder']:
    source_df, source_dfc, source_tensor, source_static = create_region_df_dfc_static(source, year)
    means[source] = {}
    for appliance in APPLIANCES_ORDER:
        means[source][appliance] = source_df[['{}_{}'.format(appliance, month) for month in range(1, 13)]].mean()
        means[source][appliance].index = range(1, 13)

# %%
pd.DataFrame(means['Boulder']).plot(kind='area', stacked=False)

# %%
pd.DataFrame(means['Houston']).plot(kind='area', stacked=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-d5712795626e> in <module>()
# ----> 1 pd.DataFrame(means['Houston']).plot(kind='area', stacked=False)
#
# KeyError: 'Houston'

# %%
source_df
# Out:
#          hvac_1     hvac_2     hvac_3     hvac_4     hvac_5      hvac_6  \
# 232   16.138151  14.620816  15.506550  14.606067  15.056300  288.439026
# 516    0.000000   0.000000   0.000000   0.225817   1.093633   52.086369
# 547    0.171450   0.129883   0.121850   0.167050   0.729517   11.363200
# 698    0.154433   0.200583   0.235067   0.248867   0.229117         NaN
# 1350   0.063100   0.056983   0.042267   3.793800   2.360433  130.364410
# 1766        NaN        NaN        NaN        NaN        NaN         NaN
# 1879   0.631433   0.492433   0.265700   0.139150   0.128300  102.587936
# 2523  17.835316  15.946950  11.642734   9.654783   6.780450         NaN
# 2903  15.165500  12.463433  16.897415  18.823750        NaN         NaN
# 2931  34.648052  31.515816  34.843868  35.915867  38.469116  299.897156
# 3104   0.005150   0.014650   0.019717   0.024117   0.063583    4.848950
# 3353        NaN        NaN        NaN        NaN        NaN         NaN
# 3734  51.784832        NaN        NaN        NaN        NaN         NaN
# 4147  25.596632  22.855165  23.286533  23.088100  43.767132  245.190002
# 4499   6.678317   4.098767   9.261233   2.010667   2.252533    4.235934
# 4601  54.858265  48.457249  47.236485  42.232216  40.419537    5.981983
# 4703   0.000300   0.000100   0.000000   0.000000   0.000100   36.532001
# 4830        NaN        NaN        NaN        NaN        NaN         NaN
# 4920   0.000000   0.000000   0.000000   0.000000   0.000000   91.454468
# 4974  15.170500  13.569822  14.520717  13.847383  14.399583  219.236237
# 5187        NaN        NaN        NaN        NaN        NaN         NaN
# 5400   0.000000   0.000000   0.000000   0.000000   0.000000   95.961868
# 5904   1.378350   1.352167   1.336400   1.140850   1.242883  116.903381
# 6083        NaN        NaN        NaN        NaN        NaN         NaN
# 6148   5.222017   4.752883   4.974833   5.039017   6.689217   29.695950
# 6264   0.000817   0.001500   0.002317   0.003383   0.001267   49.743050
# 6800        NaN        NaN        NaN        NaN        NaN         NaN
# 6888        NaN        NaN        NaN        NaN        NaN         NaN
# 7001   3.984200   3.506983   3.843667   3.502617   4.231083  171.209885
# 7818   0.000500   0.000200   0.000300   0.000100   0.000050   34.393898
# 8273   0.308983   1.344250   0.166133   5.291633  19.267801  320.013245
# 8368  81.924202  74.103401  79.248634  77.429779  80.904114  122.193130
# 8395   0.053850   0.054367   0.077967   0.085883   0.184917  170.535049
# 8555   0.004967   0.005750   0.040800   0.066800   0.002850    8.904866
# 8622   0.404850   0.373883   0.319133   0.302800   0.719233   38.092716
# 8729   0.529650   0.452683   0.731617        NaN        NaN         NaN
# 8862   0.515083   0.735617   0.335917   0.312133   0.274783   25.600183
# 9085   0.020750   0.019400   0.011667   0.025233   0.019367    5.957450
# 9142        NaN        NaN        NaN        NaN        NaN         NaN
# 9156   0.003100   0.002017   0.000300   0.001033   0.000100   35.403667
# 9341   0.000000   0.000000  19.410015  32.204617  29.057350  281.944153
# 9818   0.000050   0.000000   0.974733   0.000000   0.000000  288.385864
# 9958   0.005817   0.001350   0.000550   0.003150   0.046283   18.963984
#
#           hvac_7      hvac_8      hvac_9    hvac_10       ...         \
# 232   550.919983  553.263855  232.458511  17.814966       ...
# 516    62.062866   65.778763    7.129300   0.000000       ...
# 547    43.214214   44.240582   16.611950   0.217850       ...
# 698          NaN         NaN         NaN        NaN       ...
# 1350   82.873398   81.036430    0.019950   1.518250       ...
# 1766         NaN         NaN         NaN        NaN       ...
# 1879   53.725433   79.044380    8.830234   0.085783       ...
# 2523         NaN         NaN         NaN        NaN       ...
# 2903         NaN         NaN         NaN        NaN       ...
# 2931  431.989410  457.655518  241.760452  28.426817       ...
# 3104    1.273000   17.447166    2.857200   0.029783       ...
# 3353         NaN         NaN         NaN        NaN       ...
# 3734         NaN         NaN         NaN        NaN       ...
# 4147  233.771149  177.682541  241.087341  58.154514       ...
# 4499    2.462167    4.311967    2.802284   4.827967       ...
# 4601   17.862934    5.987250    3.875917  37.092751       ...
# 4703   66.387131   80.433769   44.981083   0.658433       ...
# 4830         NaN         NaN         NaN        NaN       ...
# 4920  126.778915  109.917900   13.411901   0.000000       ...
# 4974  491.135071  460.257111  220.316269  13.850300       ...
# 5187         NaN         NaN         NaN        NaN       ...
# 5400  148.888443  159.783020   86.943550   0.000000       ...
# 5904   53.017918    0.901667    6.486834   1.047550       ...
# 6083         NaN         NaN         NaN        NaN       ...
# 6148   40.051964   56.940536   14.044733   6.156500       ...
# 6264   22.882349    0.000617    0.003367   0.002250       ...
# 6800         NaN         NaN         NaN        NaN       ...
# 6888         NaN         NaN         NaN        NaN       ...
# 7001  162.850204  348.754669  261.794525  13.101616       ...
# 7818   74.380074  109.792679   49.471302   0.000000       ...
# 8273  343.153748  327.875885  111.534233   0.015317       ...
# 8368  147.185547  289.801239  102.846718  80.627716       ...
# 8395  371.588562  506.237915   92.417336   0.149233       ...
# 8555   18.654301   12.172350    2.881600   0.003500       ...
# 8622   53.530300   34.518803    1.958000   0.290350       ...
# 8729         NaN         NaN         NaN        NaN       ...
# 8862   25.827984   23.304066    9.269717   0.553317       ...
# 9085   32.116615   60.832169    0.026900   0.016500       ...
# 9142         NaN         NaN         NaN        NaN       ...
# 9156   88.141518  105.203400    9.550016   0.000133       ...
# 9341         NaN         NaN         NaN        NaN       ...
# 9818  399.163635  428.160889  211.635651   0.000000       ...
# 9958   44.360218   82.982353    6.678117   0.002450       ...
#
#           dr_11       dr_12  num_rooms    area  num_bedrooms  num_floors  \
# 232   42.468552   28.940968        NaN  2228.0           NaN         NaN
# 516         NaN         NaN        NaN  2379.0           NaN         NaN
# 547   77.767265  118.365952        NaN  2920.0           NaN         NaN
# 698         NaN         NaN        NaN  2370.0           NaN         NaN
# 1350  30.199467   39.240002        NaN  2332.0           NaN         NaN
# 1766  27.460917   43.629734        NaN  2564.0           NaN         NaN
# 1879        NaN         NaN        NaN  4123.0           NaN         NaN
# 2523        NaN         NaN        NaN  4306.0           NaN         NaN
# 2903        NaN         NaN        NaN  3049.0           NaN         NaN
# 2931  58.614750   41.292316        NaN  1143.0           NaN         NaN
# 3104  28.746334   20.781282        NaN  1539.0           NaN         NaN
# 3353        NaN         NaN        NaN  2207.0           NaN         NaN
# 3734        NaN         NaN        NaN  4673.0           NaN         NaN
# 4147  47.367767   11.389267        NaN     NaN           NaN         NaN
# 4499  54.359486   49.652897        NaN  2438.0           NaN         NaN
# 4601        NaN         NaN        NaN     NaN           NaN         NaN
# 4703        NaN         NaN        NaN  1985.0           NaN         NaN
# 4830  86.161339  102.610252        NaN  3971.0           NaN         NaN
# 4920   9.835033   41.793434        NaN  3311.0           NaN         NaN
# 4974  67.429718   40.264103        NaN  2393.0           NaN         NaN
# 5187        NaN         NaN        NaN  3839.0           NaN         NaN
# 5400  64.333466   98.016899        NaN     NaN           NaN         NaN
# 5904        NaN         NaN        NaN  2352.0           NaN         NaN
# 6083        NaN         NaN        NaN  1480.0           NaN         NaN
# 6148   5.378383    2.899867        NaN  2722.0           NaN         NaN
# 6264  11.167933    5.561083        NaN  1030.0           NaN         NaN
# 6800        NaN         NaN        NaN  3199.0           NaN         NaN
# 6888        NaN         NaN        NaN  3409.0           NaN         NaN
# 7001  46.633965   42.072147        NaN  2047.0           NaN         NaN
# 7818        NaN         NaN        NaN   928.0           NaN         NaN
# 8273  79.701599   85.967484        NaN  6147.0           NaN         NaN
# 8368        NaN         NaN        NaN  2055.0           NaN         NaN
# 8395  33.903633   13.866684        NaN  1559.0           NaN         NaN
# 8555  35.171898   19.384632        NaN     NaN           NaN         NaN
# 8622  37.188667   28.466333        NaN  1032.0           NaN         NaN
# 8729        NaN         NaN        NaN  2360.0           NaN         NaN
# 8862   0.308233    1.159867        NaN   928.0           NaN         NaN
# 9085  76.483284   55.968918        NaN  1763.0           NaN         NaN
# 9142  16.525949   16.650034        NaN  2277.0           NaN         NaN
# 9156        NaN         NaN        NaN  1589.0           NaN         NaN
# 9341        NaN         NaN        NaN  2958.0           NaN         NaN
# 9818  30.041084   51.272167        NaN  2157.0           NaN         NaN
# 9958        NaN         NaN        NaN  1176.0           NaN         NaN
#
#       area_first  area_second  area_third  total_occupants
# 232       1086.0        638.0         NaN              NaN
# 516       1522.0        117.0         NaN              NaN
# 547       1772.0       1148.0         NaN              NaN
# 698        966.0        756.0         NaN              NaN
# 1350       786.0        798.0         NaN              NaN
# 1766      1498.0       1066.0         NaN              NaN
# 1879      1773.0       1200.0         NaN              NaN
# 2523      2464.0        400.0         NaN              NaN
# 2903      1705.0          NaN         NaN              NaN
# 2931      1143.0          NaN         NaN              NaN
# 3104       798.0        741.0         NaN              NaN
# 3353       885.0        692.0         NaN              NaN
# 3734      1689.0       1430.0         NaN              NaN
# 4147         NaN          NaN         NaN              NaN
# 4499      1012.0        868.0         NaN              NaN
# 4601         NaN          NaN         NaN              NaN
# 4703      1412.0        573.0         NaN              NaN
# 4830      1873.0       1367.0         NaN              NaN
# 4920      1940.0        595.0         NaN              NaN
# 4974      1245.0       1148.0         NaN              NaN
# 5187      1558.0        723.0         NaN              NaN
# 5400         NaN          NaN         NaN              NaN
# 5904       964.0        744.0         NaN              NaN
# 6083      1068.0        412.0         NaN              NaN
# 6148      2282.0        440.0         NaN              NaN
# 6264      1030.0          NaN         NaN              NaN
# 6800      1334.0       1515.0         NaN              NaN
# 6888         NaN          NaN         NaN              NaN
# 7001      1386.0        661.0         NaN              NaN
# 7818       928.0          NaN         NaN              NaN
# 8273      2330.0       2606.0         NaN              NaN
# 8368      1608.0          NaN         NaN              NaN
# 8395       798.0        761.0         NaN              NaN
# 8555         NaN          NaN         NaN              NaN
# 8622       581.0        451.0         NaN              NaN
# 8729      1327.0       1033.0         NaN              NaN
# 8862       928.0          NaN         NaN              NaN
# 9085      1112.0        651.0         NaN              NaN
# 9142       798.0        761.0         NaN              NaN
# 9156       750.0        839.0         NaN              NaN
# 9341       988.0       1080.0         NaN              NaN
# 9818      1113.0       1044.0         NaN              NaN
# 9958       564.0        612.0         NaN              NaN
#
# [43 rows x 128 columns]

# %%
data_path = os.path.expanduser("~/git/scalable-nilm/create_dataset/metadata/all_regions_years_cleaned_z_score_5.pkl")

out_overall = pickle.load(open(data_path, 'r'))

# %%
out_overall[2014]['Boulder'].columns
# Out:
# Index([u'hvac_1', u'hvac_2', u'hvac_3', u'hvac_4', u'hvac_5', u'hvac_6',
#        u'hvac_7', u'hvac_8', u'hvac_9', u'hvac_10',
#        ...
#        u'dr_11', u'dr_12', u'house_num_rooms', u'area', u'num_bedrooms',
#        u'num_floors', u'area_first', u'area_second', u'area_third',
#        u'num_occupants'],
#       dtype='object', length=128)
